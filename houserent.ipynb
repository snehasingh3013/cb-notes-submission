# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os

# %%
df = pd.read_csv("House_Rent.csv")
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
df.head(10)
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
# 5  2022-04-29    2   7000   600  Ground out of 1   Super Area
# 6  2022-06-21    2  10000   700  Ground out of 4   Super Area
# 7  2022-06-21    1   5000   250       1 out of 2   Super Area
# 8  2022-06-07    2  26000   800       1 out of 2  Carpet Area
# 9  2022-06-20    2  10000  1000       1 out of 3  Carpet Area
#
#                      Area Locality     City Furnishing Status  \
# 0                           Bandel  Kolkata       Unfurnished
# 1         Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished
# 2          Salt Lake City Sector 2  Kolkata    Semi-Furnished
# ...

# %%
df.nunique()
# Out:
# Posted On              81
# BHK                     6
# Rent                  243
# Size                  615
# Floor                 480
# Area Type               3
# Area Locality        2235
# City                    6
# Furnishing Status       3
# Tenant Preferred        3
# Bathroom                8
# Point of Contact        3
# dtype: int64

# %%
for i in ['BHK','Area Type','City','Furnishing Status','Tenant Preferred','Bathroom']:
    print(df[i].unique())
    print(df[i].nunique())
    print()
# Out:
# [2 1 3 6 4 5]
# 6
#
# ['Super Area' 'Carpet Area' 'Built Area']
# 3
#
# ['Kolkata' 'Mumbai' 'Bangalore' 'Delhi' 'Chennai' 'Hyderabad']
# 6
#
# ['Unfurnished' 'Semi-Furnished' 'Furnished']
# 3
#
# ['Bachelors/Family' 'Bachelors' 'Family']
# 3
#
# [ 2  1  3  5  4  6  7 10]
# 8

# %%
#The above are the required Features to predict the Rent of a House

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
df.size
# Out:
# 56952

# %%
df.shape
# Out:
# (4746, 12)

# %%
df.corr()
# Out:
#                BHK      Rent      Size  Bathroom
# BHK       1.000000  0.369718  0.716145  0.794885
# Rent      0.369718  1.000000  0.413551  0.441215
# Size      0.716145  0.413551  1.000000  0.740703
# Bathroom  0.794885  0.441215  0.740703  1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,cmap='Greens')
plt.show()

# %%
px.scatter(df,df.Rent,df.Size,color='City',
           size='Rent',template='plotly_dark')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='BHK',data=df,palette='Pastel2')
plt.show()

# %%
plt.figure(figsize=(5,7))
sns.countplot(x='Area Type',data=df,palette='Accent_r')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='City',data=df,palette='Paired')
plt.show()

# %%
px.scatter(df,df.Rent,df['Area Locality'],color='Rent',
           size='Rent',template='plotly_dark')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(5,7))
sns.countplot(x='Furnishing Status',data=df,palette='Greens')
plt.show()

# %%
plt.figure(figsize=(13,7))
sns.color_palette('crest',as_cmap=True)
sns.countplot(x='Bathroom',data=df)
plt.show()

# %%
plt.figure(figsize=(5,7))
sns.countplot(x='Tenant Preferred',data=df,palette='cool_r')
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(x='City',y='Rent',data=df)
plt.show()

# %%
sns.jointplot('Rent','Size',df,kind='reg',color='g')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,7))
sns.pairplot(df)
plt.show()

# %%
# Dataset Glossary (Column-Wise)
# BHK: Number of Bedrooms, Hall, Kitchen.
# Rent: Rent of the Houses/Apartments/Flats.
# Size: Size of the Houses/Apartments/Flats in Square Feet.
# Floor: Houses/Apartments/Flats situated in which Floor and Total Number of Floors (Example: Ground out of 2, 3 out of 5, etc.)
# Area Type: Size of the Houses/Apartments/Flats calculated on either Super Area or Carpet Area or Build Area.
# Area Locality: Locality of the Houses/Apartments/Flats.
# City: City where the Houses/Apartments/Flats are Located.
# Furnishing Status: Furnishing Status of the Houses/Apartments/Flats, either it is Furnished or Semi-Furnished or Unfurnished.
# Tenant Preferred: Type of Tenant Preferred by the Owner or Agent.¶
# Bathroom: Number of Bathrooms.
# Point of Contact: Whom should you contact for more information regarding the Houses/Apartments/Flats.

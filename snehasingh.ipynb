# %%
import pandas as pd 
import numpy as np 
import sklearn 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_boston
var = load_boston()

# %%
df = pd.DataFrame(var.data, columns=var.feature_names)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
df = pd.DataFrame(data = np.random.random(size=(10,13)), columns = ['CRIM','ZN','INDUS','CHAS', 'NOX', 'RM','AGE', 'DIS','RAD','TAX','PTRATIO','B','LSTAT'])
df.boxplot()

# %%
x1 =df[['NOX','RM','DIS','PTRATIO']]
y1 =df['CRIM']

# %%
pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
  x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size =0.33,random_state = 5 )
  x_train.shape, x_test.shape, y_train.shape , y_test.shape
# Out:
# ((6, 4), (4, 4), (6,), (4,))

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
from sklearn.linear_model import LinearRegression 
lr=LinearRegression(normalize = True)
lr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py:145: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   FutureWarning,
# LinearRegression(normalize=True)

# %%
predictions = lr.predict(x_test)
lr.score(x_test,y_test)
# Out:
# -18.782653620656486

# %% [markdown]
# XGBoost Regressor

# %%
from xgboost import XGBRegressor

regressor = XGBRegressor()

# %%
regressor.fit(x_train,y_train)
# Out:
# [07:22:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
#prediction on training data
x_pred = regressor.predict(x_train)

# %%
y_train
# Out:
# 7    0.721086
# 1    0.270230
# 0    0.401021
# 8    0.869803
# 6    0.177517
# 3    0.019652
# Name: CRIM, dtype: float64

# %%
x_pred
# Out:
# array([0.7208066 , 0.27076608, 0.40073878, 0.8673756 , 0.17795172,
#        0.02269003], dtype=float32)

# %%
#R squared values 
r2_train = metrics.r2_score(y_train, x_pred)

# %%
print('R sqaured value = ', r2_train)
# Out:
# R sqaured value =  0.9999705088774639

# %%
#prediction on test data
y_pred = regressor.predict(x_test)

# %%
#R squared values 
r2_train = metrics.r2_score(y_test, y_pred)

# %%
print('R sqaured value = ', r2_train)
# Out:
# R sqaured value =  -2.648795677389342

# %%
predictions = [round(value) for value in y_pred]

# %%
from math import sqrt

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
rmse_1 = sqrt(mean_squared_error(y_test,y_pred))
rmse_1
# Out:
# 0.4616009668752268

# %%
res_1= y_test-y_pred
res_1
# Out:
# 9    0.476294
# 5    0.690488
# 2    0.132951
# 4   -0.361934
# Name: CRIM, dtype: float64

# %%
y_test
# Out:
# 9    0.609498
# 5    0.945537
# 2    0.277865
# 4    0.491590
# Name: CRIM, dtype: float64

# %%
plt.scatter(y_test,res_1,color = 'black')
plt.xlabel('Residual')
plt.ylabel('y_test')
plt.axhline(y=0)

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
error_1 = mae(y_test,y_pred)

# %%
print('Mean absolute error errror for XGBoost model:', error_1)
# Out:
# Mean absolute error errror for XGBoost model: 0.41541666842840663

# %% [markdown]
# **LINEAR REGRESSION**

# %%
x =df[['NOX','RM','DIS','PTRATIO','LSTAT' ]]
y=df['CRIM']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor_1= LinearRegression()

# %%
regressor_1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction = regressor_1.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(y_test,y_prediction)
# Out:
# -45.06598263070691

# %%
from math import sqrt

# %%
rmse_2= sqrt(mean_squared_error(y_test,y_prediction))
rmse_2
# Out:
# 0.7512045006472352

# %%
res_2= y_test-y_prediction
res_2
# Out:
# 4   -0.549895
# 1   -0.908973
# Name: CRIM, dtype: float64

# %%
plt.scatter(y_test,res_2,color = 'red')
plt.xlabel('Residual')
plt.ylabel('y_test')
plt.axhline(y=0)

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
error_2 = mae(y_test,y_prediction)

# %%
print('Mean absolute error errror for XGBoost model:', error_2)
# Out:
# Mean absolute error errror for XGBoost model: 0.7294339708072994

# %%
sns.pairplot(df, x_vars=['NOX','RM','DIS','PTRATIO','LSTAT'], y_vars='CRIM', height=9, aspect=0.6, kind='reg')

# %% [markdown]
# **FEATURE TRANSFORM**

# %%
plt.figure( figsize = (10,7), dpi = 120)
plt.hist(df['PTRATIO'], bins = 100, color = 'red')
plt.xlabel('PTRATIO')
plt.ylabel('frequncy')
plt.show()

# %%
label_encoded = df['AGE']
label_encoded.value_counts()
# Out:
# 0.195009    1
# 0.480348    1
# 0.260946    1
# 0.929766    1
# 0.190193    1
# 0.415936    1
# 0.915424    1
# 0.467748    1
# 0.576430    1
# 0.606140    1
# Name: AGE, dtype: int64

# %%
df['AGE'].unique()
# Out:
# array([0.19500943, 0.48034844, 0.26094643, 0.92976606, 0.19019276,
#        0.41593609, 0.91542423, 0.46774773, 0.57642969, 0.60614047])

# %%
df['AGE'].value_counts()
# Out:
# 0.195009    1
# 0.480348    1
# 0.260946    1
# 0.929766    1
# 0.190193    1
# 0.415936    1
# 0.915424    1
# 0.467748    1
# 0.576430    1
# 0.606140    1
# Name: AGE, dtype: int64

# %%
mean = []

for i in df['AGE'].unique():
    mean.append(df['TAX'][df['AGE'] == i].mean())

# %%
plt.figure(figsize = (6,7), dpi = 100)
plt.bar(df['AGE'].unique(), mean)
plt.xlabel('AGE')
plt.ylabel("mean TAX")
# Out:
# Text(0, 0.5, 'mean TAX')

# %%
len(df['AGE'].unique())
# Out:
# 10

# %%
df['AGE'].max()
# Out:
# 0.9297660589698702

# %%
df['AGE'].min()
# Out:
# 0.19019275642810707

# %%
for i in df.columns:
    tmp = df[i].isnull().sum()/len(df)
    if tmp> 0.70:
        print("Removing column '"+i+"' with missing value ratio", tmp)
        df = df.drop(columns = [i])

# %%
df.head()
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0  0.401021  0.693214  0.930260  0.244125  0.730248  0.672046  0.195009
# 1  0.270230  0.355625  0.903075  0.755990  0.956161  0.180384  0.480348
# 2  0.277865  0.443577  0.794020  0.505462  0.143398  0.778496  0.260946
# 3  0.019652  0.452936  0.810814  0.799198  0.351843  0.234732  0.929766
# 4  0.491590  0.840271  0.057999  0.321958  0.757679  0.050601  0.190193
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT
# 0  0.115348  0.825389  0.885594  0.071687  0.069996  0.478365
# 1  0.431617  0.064165  0.417687  0.048457  0.211430  0.879712
# 2  0.971286  0.324297  0.760583  0.463979  0.317397  0.511897
# 3  0.811461  0.487867  0.688479  0.758725  0.441624  0.267130
# 4  0.497623  0.998574  0.775380  0.107330  0.213215  0.948718

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings(action = 'ignore')
plt.style.use(['seaborn-bright', 'dark_background'])

# %%
import seaborn as sns
sns.countplot(x="AGE", data=df)

# %%
sns.countplot(x="CRIM", data=df, color='pink')

# %%
# checking the the dataset distribution
df['CRIM'].value_counts()/len(df)
# Out:
# 0.401021    0.1
# 0.270230    0.1
# 0.277865    0.1
# 0.019652    0.1
# 0.491590    0.1
# 0.945537    0.1
# 0.177517    0.1
# 0.721086    0.1
# 0.869803    0.1
# 0.609498    0.1
# Name: CRIM, dtype: float64

# %%
# seperating dependent and independent variables 
#X= df[['NOX','RM','DIS','PTRATIO','LSTAT' ]]
X = df.drop(columns=['NOX','RM','DIS','PTRATIO'])

Y= df.drop(columns=['CRIM','AGE'])

# %%
#Scaling the dataset 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
#splitting the dataset 
from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0,shuffle=True)

x_train.shape, x_test.shape, y_train.shape , y_test.shape
# Out:
# ((8, 5), (2, 5), (8,), (2,))

# %% [markdown]
# **Model Building , Predictions and odds ratio**

# %%
from sklearn.linear_model import LogisticRegression as LR
Classifier = LR(class_weight = 'balanced')

# %%
X_train.shape
# Out:
# (8, 9)

# %%
Y_train.shape
# Out:
# (8, 11)

# %%
Y_train= Y_train.values.reshape(-1,1)

# %%
Y_train
# Out:
# array([[0.84027128],
#        [0.0579993 ],
#        [0.32195816],
#        [0.75767899],
#        [0.05060058],
#        [0.49762269],
#        [0.99857361],
#        [0.77538007],
#        [0.10733009],
#        [0.21321541],
#        [0.94871806],
#        [0.98383999],
#        [0.5804552 ],
#        [0.36030509],
#        [0.31490003],
#        [0.65193036],
#        [0.9775344 ],
#        [0.36939932],
#        [0.90350792],
#        [0.56217793],
#        [0.01560216],
#        [0.74781194],
#        [0.35562501],
#        [0.90307493],
#        [0.75598981],
#        [0.95616115],
#        [0.18038435],
#        [0.43161745],
#        [0.06416487],
#        [0.4176866 ],
#        [0.04845727],
#        [0.21143042],
#        [0.87971156],
#        [0.64024941],
#        [0.18561992],
#        [0.10118955],
#        [0.15239173],
#        [0.12790207],
#        [0.52749878],
#        [0.64329711],
#        [0.35848833],
#        [0.46102208],
#        [0.19847043],
# ...

# %%
X_train
# Out:
#        CRIM        ZN     INDUS      CHAS       AGE       RAD       TAX  \
# 4  0.491590  0.840271  0.057999  0.321958  0.190193  0.998574  0.775380
# 9  0.609498  0.983840  0.580455  0.360305  0.606140  0.369399  0.903508
# 1  0.270230  0.355625  0.903075  0.755990  0.480348  0.064165  0.417687
# 6  0.177517  0.640249  0.185620  0.101190  0.915424  0.643297  0.358488
# 7  0.721086  0.022759  0.804641  0.805660  0.467748  0.451860  0.596893
# 3  0.019652  0.452936  0.810814  0.799198  0.929766  0.487867  0.688479
# 0  0.401021  0.693214  0.930260  0.244125  0.195009  0.825389  0.885594
# 5  0.945537  0.332858  0.049154  0.035743  0.415936  0.020750  0.296179
#
#           B     LSTAT
# 4  0.213215  0.948718
# 9  0.015602  0.747812
# 1  0.211430  0.879712
# 6  0.198470  0.692478
# 7  0.307077  0.067462
# 3  0.441624  0.267130
# 0  0.069996  0.478365
# 5  0.337264  0.388381

# %%
X_train= X_train.values.reshape(-1,1) 
X_train
# Out:
# array([[0.49158955],
#        [0.84027128],
#        [0.0579993 ],
#        [0.32195816],
#        [0.19019276],
#        [0.99857361],
#        [0.77538007],
#        [0.21321541],
#        [0.94871806],
#        [0.60949769],
#        [0.98383999],
#        [0.5804552 ],
#        [0.36030509],
#        [0.60614047],
#        [0.36939932],
#        [0.90350792],
#        [0.01560216],
#        [0.74781194],
#        [0.27023013],
#        [0.35562501],
#        [0.90307493],
#        [0.75598981],
#        [0.48034844],
#        [0.06416487],
#        [0.4176866 ],
#        [0.21143042],
#        [0.87971156],
#        [0.17751736],
#        [0.64024941],
#        [0.18561992],
#        [0.10118955],
#        [0.91542423],
#        [0.64329711],
#        [0.35848833],
#        [0.19847043],
#        [0.69247755],
#        [0.72108641],
#        [0.0227594 ],
#        [0.80464067],
#        [0.80565983],
#        [0.46774773],
#        [0.45185994],
#        [0.59689319],
# ...

# %%
train_test_split(X, Y)
# Out:
# [       CRIM        ZN     INDUS      CHAS       AGE       RAD       TAX  \
#  4  0.491590  0.840271  0.057999  0.321958  0.190193  0.998574  0.775380
#  1  0.270230  0.355625  0.903075  0.755990  0.480348  0.064165  0.417687
#  7  0.721086  0.022759  0.804641  0.805660  0.467748  0.451860  0.596893
#  0  0.401021  0.693214  0.930260  0.244125  0.195009  0.825389  0.885594
#  3  0.019652  0.452936  0.810814  0.799198  0.929766  0.487867  0.688479
#  2  0.277865  0.443577  0.794020  0.505462  0.260946  0.324297  0.760583
#  5  0.945537  0.332858  0.049154  0.035743  0.415936  0.020750  0.296179
#
#            B     LSTAT
#  4  0.213215  0.948718
#  1  0.211430  0.879712
#  7  0.307077  0.067462
#  0  0.069996  0.478365
#  3  0.441624  0.267130
#  2  0.317397  0.511897
#  5  0.337264  0.388381  ,
#         CRIM        ZN     INDUS      CHAS       AGE       RAD       TAX  \
#  8  0.869803  0.076321  0.689685  0.920179  0.576430  0.181819  0.584583
# ...

# %%
print(X.shape)
print(Y.shape)

if X.shape[0] != Y.shape[0]:
  print("X and Y rows are mismatched, check dataset again")
# Out:
# (10, 9)
# (10, 11)

# %%
df["TAX"].plot.hist()

# %%
len(X_train.shape) == len(Y_train.shape)
# Out:
# True

# %%
Classifier.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-3b8e01bdae14> in <module>()
# ----> 1 Classifier.fit(X_train, Y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1512             dtype=_dtype,
#    1513             order="C",
# -> 1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
#    1516         check_classification_targets(y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
predicted_values = Classifier.predict(x_test)               #predicting class
predicted_probabilities = Classifier.predict_proba(x_test) #predicting probabilities

# %%
predicted_values

# %%
predicted_probabilities, predicted_probabilities.shape

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test, predicted_values)
cf

# %%
#Accuracy 
Classifier.score(x_test, y_test)

# %%
# calculating the precision score 
from sklearn.metrics import precision_score
Precision = precision_score(y_test, predicted_values)
Precision

# %%
# calculating the recall score 
from sklearn.metrics import recall_score
Recall= recall_score(y_test, predicted_values)
Recall

# %%
#manually calculating the f1
f1 = 2/((1/Precision)+(1/Recall))
f1

# %%
# calculating the f1 score 
from sklearn.metrics import f1_score
F1 = f1_score(y_test, predicted_values)
F1

# %%
# calculating precision, recall , f1-score and support at once 
from sklearn.metrics import precision_recall_fscore_support as PRF_summary 
precision, recall, f1, support = PRF_summary(y_test, predicted_values)

# %%
precision

# %%
recall

# %%
f1

# %%
from sklearn.metrics import classification_report 
k = classification_report(y_test, predicted_values)
print(k)

# %% [markdown]
# **PRECISION- RECALL CURVE**

# %%
# gathering Precision/recall scores for differrent thresholds
from sklearn.metrics import precision_recall_curve
precision_points, recall_points, threshold_points = precision_recall_curve(y_test, predicted_probabilities[:, 1])
precision_points.shape, recall_points.shape, threshold_points.shape

# %%
plt.figure(figsize = (7,5), dpi = 100)
plt.plot(threshold_points, precision_points[:-1], color = 'green', label = 'Precision')
plt.plot(threshold_points, recall_points[:-1], color = 'orange', label = 'Recall')
plt.xlabel('Threshold Points', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.title('Precision-Recall tradeoff', fontsize = 20)
plt.legend

# %% [markdown]
# ***AUC- ROC CURVE***

# %%
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, threshold = roc_curve(y_test, predicted_probabilities[:,1])

# %%
plt.figure(figsize= (7,5), dpi=100)
plt.plot(fpr, tpr, color ='green')
plt.plot([0,1],[0,1], label ='baseline', color ='red')
plt.xlabel('FPR', fontsize= 15)
plt.ylabel('TPR', fontsize= 15)
plt.title('AUC=ROC', fontsize= 15)
plt.show()
roc_auc_score(Y_test, predicted_probabiliteis[:,1])

# %% [markdown]
# **COEFFICIENT PLOT**

# %%
# arranging the data 
c = Classifier.coef_.reshape(-1)
x = X.columns 

coeff_plot = pd.DataFrame({ 
                           # 'coefficients' : c, 
                            # 'variable' : x})
# sorting the values
coeff_plot = coeff_plot.sort_values(by = 'coefficients')
coeff_plot.head()

# %%
plt.figure(figsize= (8,6), dpi = 120)
plt.barh(coeff_plot['variable'], coeff_plot['coefficients'])
plt.xlabel("coefficient Magnitude", fontsize = 20)
plt.ylabel("variables", fontsize = 20)
plt.title("coefficient plot", fontsize = 44)
